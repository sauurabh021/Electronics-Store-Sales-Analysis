# %%
import pandas as pd
import os

# %%
df = pd.read_csv('C:\\Users\\Hp\Downloads\\Sales_Data\\Sales_April_2019.csv')

files = [file for file in os.listdir('C:\\Users\\Hp\\Downloads\\Sales_Data')]

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('C:\\Users\\Hp\Downloads\\Sales_Data\\' + file)
    all_months_data = pd.concat([all_months_data, df])
    
all_months_data.to_csv("all_data.csv", index=False)
#     print(file)

# %%
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# Clean up the data!

# %%
all_data.head(50)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    176558        USB-C Charging Cable                2      11.95
# 1       NaN                         NaN              NaN        NaN
# 2    176559  Bose SoundSport Headphones                1      99.99
# 3    176560                Google Phone                1        600
# 4    176560            Wired Headphones                1      11.99
# 5    176561            Wired Headphones                1      11.99
# 6    176562        USB-C Charging Cable                1      11.95
# 7    176563  Bose SoundSport Headphones                1      99.99
# 8    176564        USB-C Charging Cable                1      11.95
# 9    176565          Macbook Pro Laptop                1       1700
# 10   176566            Wired Headphones                1      11.99
# 11   176567                Google Phone                1        600
# 12   176568    Lightning Charging Cable                1      14.95
# ...

# %% [markdown]
# Drop rows of NAN

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()

all_data = all_data.dropna(how = "all")
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# Find "Or" and delete it

# %%
all_data = all_data[all_data["Order Date"].str[0:2] != "Or"]

# %% [markdown]
# convert columns to the correct Type

# %%
all_data["Quantity Ordered"] = pd.to_numeric(all_data["Quantity Ordered"]) # Make int
all_data["Price Each"] = pd.to_numeric(all_data["Price Each"])# Make Float

all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# Add Month Column

# %%
all_data["Month"] = all_data["Order Date"].str[0:2]
all_data["Month"] = all_data["Month"].astype("int32")
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %%
all_data["Sales"] = all_data["Quantity Ordered"] * all_data["Price Each"]
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %% [markdown]
# Add City Column

# %%
# Lets use .apply()
def get_city(address):
    return address.split(',')[1]


all_data["city"] = all_data["Purchase Address"].apply(lambda x: get_city(x))

# all_data = all_data.drop(columns="column")

all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#            city
# 0        Dallas
# 2        Boston
# 3   Los Angeles
# 4   Los Angeles
# 5   Los Angeles

# %% [markdown]
# Q1: What was the best month for sales? How was earned that month?

# %%
all_data.groupby("Month").sum()
# Out:
#                                                 Order ID  \
# Month
# 1      2971502978172978172979692983442990492991253003...
# 2      1505021505031505041505051505061505071505081505...
# 3      1505331505411508121517491520361532841535441538...
# 4      1765581765591765601765601765611765621765631765...
# 5      1769781775511777781777781790761790761791341800...
# 6      2099212099222099232099242099252099262099272099...
# 7      2229102229112229122229132229142229152229162229...
# 8      2366702366712366722366732366742366752366762366...
# 9      2388342392852406362410542423432428652436672449...
# 10     2593582593592593602593612593622593632593642593...
# 11     2787972787982787992788002788012788022788032788...
# 12     2956652956662956672956682956692956702956712956...
#
#                                                  Product  Quantity Ordered  \
# Month
# 1      Lightning Charging CableiPhoneLightning Chargi...             10903
# ...

# %%
import matplotlib.pyplot as plt

months = range(1, 13)

sales_by_month = all_data.groupby(["Month"]).sum()["Sales"]

plt.bar(months, sales_by_month, color="skyblue")
plt.xticks(months)
plt.ylabel("sales in USD ($)")
plt.xlabel("Month number")


plt.show()

# %% [markdown]
# What city had the Highest number of sales

# %%
results = all_data.groupby("city").sum()
results
# Out:
#                                                          Order ID  \
# city
#  Atlanta        1765641765711765821765891766231766271766341766...
#  Austin         1765911766091766741766771766861767011767051767...
#  Boston         1765591765661765781765811765851765851766001766...
#  Dallas         1765581765691765701765771765961766021766101766...
#  Los Angeles    1765601765601765611765671765741765741765761765...
#  New York City  1765721765751765791765901765991766131766371766...
#  Portland       1765831765931766171766421766461766481766621767...
#  San Francisco  1765621765651765731765841765861765861765941765...
#  Seattle        1765631765681765881766121766241766541766631766...
#
#                                                           Product  \
# city
#  Atlanta        USB-C Charging CableLightning Charging CableBo...
#  Austin         Apple Airpods HeadphonesApple Airpods Headphon...
#  Boston         Bose SoundSport HeadphonesWired HeadphonesAppl...
# ...

# %%
import matplotlib.pyplot as plt

cities =[city for city, df in all_data.groupby("city")]

plt.bar(cities, results["Sales"])
plt.xticks(cities, rotation = 'vertical', size = 8)
plt.ylabel("Sales in USD ($)")
plt.xlabel("city Name")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Q3: What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
all_data["Order Date"] = pd.to_datetime(all_data["Order Date"])

all_data["Hour"] = all_data["Order Date"].dt.hour
all_data["Minute"] = all_data["Order Date"].dt.minute
all_data.head()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12100\1982803301.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   all_data["Order Date"] = pd.to_datetime(all_data["Order Date"])
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# ...

# %%
hours = [hour for hour, df in all_data.groupby("Hour")]

plt.plot(hours, all_data.groupby(["Hour"]).count())
plt.xticks(hours)
plt.grid()
plt.show()
# all_data.groupby(["Hour"]).count()

# %% [markdown]
# Q4: What products are most often sold together:

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#            city  Hour  Minute
# 0        Dallas     8      46
# 2        Boston    22      30
# ...

# %%
df = all_data[all_data["Order ID"].duplicated(keep=False)]

df["Grouped"] = df.groupby("Order ID")["Product"].transform(lambda x: ",".join(x))

df = df[["Order ID", 'Grouped']].drop_duplicates()
df.head(100)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12100\1285195104.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Grouped"] = df.groupby("Order ID")["Product"].transform(lambda x: ",".join(x))
#      Order ID                                            Grouped
# 3      176560                      Google Phone,Wired Headphones
# 18     176574                  Google Phone,USB-C Charging Cable
# 30     176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32     176586                AAA Batteries (4-pack),Google Phone
# 119    176672      Lightning Charging Cable,USB-C Charging Cable
# ...       ...                                                ...
# 2662   179108    Lightning Charging Cable,AAA Batteries (4-pack)
# ...

# %%
from itertools import combinations
from collections import Counter

list3 = [[2, 3], [2, 3, 4]]

count = Counter()

for sublist in list3:
    count.update(Counter(combinations(sublist, 2)))
    
print(count)
# Out:
# Counter({(2, 3): 2, (2, 4): 1, (3, 4): 1})

# %%
count = Counter()

for row in df["Grouped"]:
    row_list = row.split(",")
    count.update(Counter(combinations(row_list, 2)))
    
count.most_common(10)
# for key, value in count.most_common(10):
#     print(key, value)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 160),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %% [markdown]
# Q5: What product sold most? Why do you think it sold the most?

# %%
product_group = all_data.groupby("Product")
quantity_ordered = product_group.sum()["Quantity Ordered"]

product = [product for product, df in product_group]

plt.bar(product, quantity_ordered)
plt.ylabel("Quantity Order")
plt.xlabel("Product")
plt.xticks(product, rotation = "vertical", size = 8)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 product_group = all_data.groupby("Product")
# ----> 2 quantity_ordered = product_group.sum()["Quantity Ordered"]
#       4 product = [product for product, df in product_group]
#       6 plt.bar(product, quantity_ordered)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:3053, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3048 else:
#    3049     # If we are grouping on categoricals we want unobserved categories to
#    3050     # return zero, rather than the default of NaN which the reindexing in
#    3051     # _agg_general() returns. GH #31422
#    3052     with com.temp_setattr(self, "observed", True):
# -> 3053         result = self._agg_general(
#    3054             numeric_only=numeric_only,
# ...

# %%
all_data.head()
